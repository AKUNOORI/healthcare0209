# %%
# Read PostgreSQL incremental data

df = spark.read.format("jdbc") \
    .option("url", jdbc_url) \
    .option("dbtable", table_name) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "org.postgresql.Driver") \
    .load()

# Merge into bronze table

df.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable("healthcare0209.healthcare0209_bronze.billing")

# %%
# %sql
select count(*) from healthcare0209.healthcare0209_bronze.billing
