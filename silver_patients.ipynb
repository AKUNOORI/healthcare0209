# %%
# %sql
create or replace table healthcare0209.healthcare0209_silver.patients
as
select distinct patient_id, first_name, last_name, gender, dob, city, state, country, phone, updated_at from healthcare0209.healthcare0209_bronze.patients order by patient_id

# %%
# %sql
select count(*) from healthcare0209.healthcare0209_silver.patients
