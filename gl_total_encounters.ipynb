# %%
# %sql
create or replace table healthcare0209.healthcare0209_gold.kpi_total_active_encounters as
select count(*) as total_active_encounters from healthcare0209.healthcare0209_silver.encounters

# %%
# %sql
select * from healthcare0209.healthcare0209_gold.kpi_total_active_encounters
