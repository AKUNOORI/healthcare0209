# %%
# %sql
create or replace table healthcare0209.healthcare0209_silver.hospitals
as
select distinct hospital_id, name, city, capacity, updated_at from healthcare0209.healthcare0209_bronze.hospitals order by hospital_id
