# %%
# %sql
create or replace view healthcare0209.healthcare0209_gold.v_total_patients as
select * from healthcare0209.healthcare0209_gold.patients

# %%
# %sql
select * from healthcare0209.healthcare0209_gold.v_total_patients
