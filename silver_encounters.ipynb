# %%
# %sql
create or replace table healthcare0209.healthcare0209_silver.encounters as
select distinct encounter_id, patient_id, doctor_id, hospital_id, admission_date, discharge_date, reason, updated_at from healthcare0209.healthcare0209_bronze.encounters order by encounter_id

# %%
# %sql
select * from healthcare0209.healthcare0209_silver.encounters order by encounter_id
