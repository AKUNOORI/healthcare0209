# %%
# %sql
create or replace table healthcare0209.healthcare0209_gold.total_encounters_by_year
using delta
as
select count(*) as total_encounters, year(admission_date) as admission_year from healthcare0209.healthcare0209_silver.encounters
group by year(admission_date)
order by year(admission_date)
