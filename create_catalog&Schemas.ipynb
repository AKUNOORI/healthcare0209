# %%
# %sql
create CATALOG if not exists healthcare0209

# %%
# %sql
create schema if not exists  healthcare0209.healthcare0209_bronze

# %%
# %sql
create schema if not exists  healthcare0209.healthcare0209_silver

# %%
# %sql
create schema if not exists healthcare0209.healthcare0209_gold
