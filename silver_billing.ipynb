# %%
# %sql
create or replace table healthcare0209.healthcare0209_silver.billing
as
select distinct bill_id, 
    patient_id, 
    total_amount, 
    insurance_amount, 
    paid_amount, 
    status, 
    updated_at 
    from healthcare0209.healthcare0209_bronze.billing
where total_amount is not null

# %%
# %sql
select * from healthcare0209.healthcare0209_silver.billing order by bill_id

# %%
# %sql
select * from healthcare0209.healthcare0209_bronze.patients
