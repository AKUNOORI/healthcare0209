# %%
# %sql
create or replace view healthcare0209.healthcare0209_gold.v_allTotals
as
select * from healthcare0209.healthcare0209_gold.allTotalValues

# %%
# %sql
select * from healthcare0209.healthcare0209_gold.v_allTotals
