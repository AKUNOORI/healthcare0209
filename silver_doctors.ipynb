# %%
# %sql
create or replace table healthcare0209.healthcare0209_silver.doctors
as
select distinct doctor_id, name, specialization, experience_years, updated_at from healthcare0209.healthcare0209_bronze.doctors order by doctor_id
